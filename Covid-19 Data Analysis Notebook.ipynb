# %% [markdown]
# # Welcome to Covid19 Data Analysis Notebook

# %% [markdown]
# Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 

print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# # Task 2

# %% [markdown]
# # Task 2.1: importing covid19 dataset

# %% [markdown]
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
corona_dataset_csv = pd.read_csv('Dataset/covid19_Confirmed_dataset.csv')
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/30/20  7/1/20  \
# 0        0        0        0        0        0        0  ...    31517   31836
# 1        0        0        0        0        0        0  ...     2535    2580
# 2        0        0        0        0        0        0  ...    13907   14272
# 3        0        0        0        0        0        0  ...      855     855
# 4        0        0        0        0        0        0  ...      284     291
# 5        0        0        0        0        0        0  ...       69      69
# 6        0        0        0        0        0        0  ...    64530   67197
# 7        0        0        0        0        0        0  ...    25542   26065
# 8        0        0        0        0        0        0  ...      108     108
# 9        0        0        0        0        3        4  ...     3203    3211
#
#    7/2/20  7/3/20  7/4/20  7/5/20  7/6/20  7/7/20  7/8/20  7/9/20
# 0   32022   32324   32672   32951   33190   33384   33594   33908
# 1    2662    2752    2819    2893    2964    3038    3106    3188
# 2   14657   15070   15500   15941   16404   16879   17348   17808
# 3     855     855     855     855     855     855     855     855
# 4     315     328     346     346     346     386     386     396
# 5      69      68      68      68      70      70      70      73
# 6   69941   72786   75376   77815   80447   83426   87030   90693
# 7   26658   27320   27900   28606   28936   29285   29820   30346
# 8     108     108     108     108     108     111     112     113
# 9    3211    3405    3419    3429    3433    3440    3453    3467
#
# [10 rows x 174 columns]

# %% [markdown]
# Let's check the shape of the dataframe

# %%
corona_dataset_csv.shape
# Out:
# (266, 174)

# %% [markdown]
# # Task 2.2: Delete the useless columns

# %%
corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  6/30/20  7/1/20  \
# 0        0        0        0        0        0        0  ...    31517   31836
# 1        0        0        0        0        0        0  ...     2535    2580
# 2        0        0        0        0        0        0  ...    13907   14272
# 3        0        0        0        0        0        0  ...      855     855
# 4        0        0        0        0        0        0  ...      284     291
# 5        0        0        0        0        0        0  ...       69      69
# 6        0        0        0        0        0        0  ...    64530   67197
# 7        0        0        0        0        0        0  ...    25542   26065
# 8        0        0        0        0        0        0  ...      108     108
# 9        0        0        3        4        4        4  ...     3203    3211
#
#    7/2/20  7/3/20  7/4/20  7/5/20  7/6/20  7/7/20  7/8/20  7/9/20
# 0   32022   32324   32672   32951   33190   33384   33594   33908
# 1    2662    2752    2819    2893    2964    3038    3106    3188
# 2   14657   15070   15500   15941   16404   16879   17348   17808
# 3     855     855     855     855     855     855     855     855
# 4     315     328     346     346     346     386     386     396
# 5      69      68      68      68      70      70      70      73
# 6   69941   72786   75376   77815   80447   83426   87030   90693
# 7   26658   27320   27900   28606   28936   29285   29820   30346
# 8     108     108     108     108     108     111     112     113
# 9    3211    3405    3419    3429    3433    3440    3453    3467
#
# [10 rows x 172 columns]

# %% [markdown]
# # Task 2.3: Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  6/30/20  7/1/20  \
# Country/Region                                           ...
# Afghanistan                0        0        0        0  ...    31517   31836
# Albania                    0        0        0        0  ...     2535    2580
# Algeria                    0        0        0        0  ...    13907   14272
# Andorra                    0        0        0        0  ...      855     855
# Angola                     0        0        0        0  ...      284     291
# Antigua and Barbuda        0        0        0        0  ...       69      69
# Argentina                  0        0        0        0  ...    64530   67197
# Armenia                    0        0        0        0  ...    25542   26065
# Australia                  5        6        9        9  ...     7920    8001
# Austria                    0        0        0        0  ...    17766   17873
#
#                      7/2/20  7/3/20  7/4/20  7/5/20  7/6/20  7/7/20  7/8/20  \
# Country/Region
# Afghanistan           32022   32324   32672   32951   33190   33384   33594
# Albania                2662    2752    2819    2893    2964    3038    3106
# Algeria               14657   15070   15500   15941   16404   16879   17348
# Andorra                 855     855     855     855     855     855     855
# Angola                  315     328     346     346     346     386     386
# Antigua and Barbuda      69      68      68      68      70      70      70
# Argentina             69941   72786   75376   77815   80447   83426   87030
# Armenia               26658   27320   27900   28606   28936   29285   29820
# Australia              8066    8260    8443    8583    8755    8886    9056
# Austria               17941   18050   18165   18280   18365   18421   18513
#
#                      7/9/20
# Country/Region
# Afghanistan           33908
# Albania                3188
# Algeria               17808
# Andorra                 855
# Angola                  396
# Antigua and Barbuda      73
# Argentina             90693
# Armenia               30346
# Australia              9374
# Austria               18615
#
# [10 rows x 170 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (188, 170)

# %% [markdown]
# # Task 2.4: Visualizing data related to a country for example China

# %% [markdown]
# visualization always helps for better understanding of our data

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['India'].plot()
plt.legend()

# %% [markdown]
# # Task3: Calculating a good measure

# %% [markdown]
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_aggregated.loc['China'].plot()

# %% [markdown]
# # Task 3.1: caculating the first derivative of the curve

# %%
corona_dataset_aggregated.loc['Israel'].diff().plot()

# %% [markdown]
# # Task 3.2: find maxmimum infection rate for China

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc['Italy'].diff().max()
# Out:
# 6557.0

# %%
corona_dataset_aggregated.loc['India'].diff().max()
# Out:
# 26506.0

# %% [markdown]
# # Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max infection rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  7/1/20  7/2/20  \
# Country/Region                                           ...
# Afghanistan                0        0        0        0  ...   31836   32022
# Albania                    0        0        0        0  ...    2580    2662
# Algeria                    0        0        0        0  ...   14272   14657
# Andorra                    0        0        0        0  ...     855     855
# Angola                     0        0        0        0  ...     291     315
# Antigua and Barbuda        0        0        0        0  ...      69      69
# Argentina                  0        0        0        0  ...   67197   69941
# Armenia                    0        0        0        0  ...   26065   26658
# Australia                  5        6        9        9  ...    8001    8066
# Austria                    0        0        0        0  ...   17873   17941
#
#                      7/3/20  7/4/20  7/5/20  7/6/20  7/7/20  7/8/20  7/9/20  \
# Country/Region
# Afghanistan           32324   32672   32951   33190   33384   33594   33908
# Albania                2752    2819    2893    2964    3038    3106    3188
# Algeria               15070   15500   15941   16404   16879   17348   17808
# Andorra                 855     855     855     855     855     855     855
# Angola                  328     346     346     346     386     386     396
# Antigua and Barbuda      68      68      68      70      70      70      73
# Argentina             72786   75376   77815   80447   83426   87030   90693
# Armenia               27320   27900   28606   28936   29285   29820   30346
# Australia              8260    8443    8583    8755    8886    9056    9374
# Austria               18050   18165   18280   18365   18421   18513   18615
#
#                      max infection rate
# Country/Region
# Afghanistan                       915.0
# Albania                            90.0
# Algeria                           475.0
# Andorra                            79.0
# Angola                             47.0
# Antigua and Barbuda                39.0
# Argentina                        3663.0
# Armenia                           771.0
# Australia                         497.0
# Austria                          1321.0
#
# [10 rows x 171 columns]

# %% [markdown]
# # Task 3.4: Create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['max infection rate'])

# %%
corona_data.head(10)
# Out:
#                      max infection rate
# Country/Region
# Afghanistan                       915.0
# Albania                            90.0
# Algeria                           475.0
# Andorra                            79.0
# Angola                             47.0
# Antigua and Barbuda                39.0
# Argentina                        3663.0
# Armenia                           771.0
# Australia                         497.0
# Austria                          1321.0

# %% [markdown]
# # Task4:

# %% [markdown]
# >--Importing the WorldHappinessReport.csv dataset

# %% [markdown]
# >--selecting needed columns for our analysis

# %% [markdown]
# >--join the datasets

# %% [markdown]
# >--calculate the correlations as the result of our analysis

# %% [markdown]
# # Task 4.1 : importing the dataset

# %%
world_happiness_report = pd.read_csv("Dataset/worldwide_happiness_report.csv")
world_happiness_report.head(10)
# Out:
#   Country (region)  Overall Rank  SD of Ladder  Positive affect  \
# 0          Finland             1             4             41.0
# 1          Denmark             2            13             24.0
# 2           Norway             3             8             16.0
# 3          Iceland             4             9              3.0
# 4      Netherlands             5             1             12.0
# 5      Switzerland             6            11             44.0
# 6           Sweden             7            18             34.0
# 7      New Zealand             8            15             22.0
# 8           Canada             9            23             18.0
# 9          Austria            10            10             64.0
#
#    Negative affect  Social support  Log of GDP\nper capita  \
# 0             10.0             2.0                    22.0
# 1             26.0             4.0                    14.0
# 2             29.0             3.0                     7.0
# 3              3.0             1.0                    15.0
# 4             25.0            15.0                    12.0
# 5             21.0            13.0                     8.0
# 6              8.0            25.0                    13.0
# 7             12.0             5.0                    26.0
# 8             49.0            20.0                    19.0
# 9             24.0            31.0                    16.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0
# 5                       4.0
# 6                      17.0
# 7                      14.0
# 8                       8.0
# 9                      15.0

# %%
world_happiness_report.shape
# Out:
# (156, 8)

# %% [markdown]
# # Task 4.2: let's drop the useless columns

# %%
columns_to_dropped = ['SD of Ladder','Positive affect','Negative affect']
world_happiness_report.drop(columns_to_dropped,axis=1)
# Out:
#              Country (region)  Overall Rank  Social support  \
# 0                     Finland             1             2.0
# 1                     Denmark             2             4.0
# 2                      Norway             3             3.0
# 3                     Iceland             4             1.0
# 4                 Netherlands             5            15.0
# ..                        ...           ...             ...
# 151                    Rwanda           152           144.0
# 152                  Tanzania           153           131.0
# 153               Afghanistan           154           151.0
# 154  Central African Republic           155           155.0
# 155               South Sudan           156           148.0
#
#      Log of GDP\nper capita  Healthy life\nexpectancy
# 0                      22.0                      27.0
# 1                      14.0                      23.0
# 2                       7.0                      12.0
# 3                      15.0                      13.0
# 4                      12.0                      18.0
# ..                      ...                       ...
# 151                   132.0                     103.0
# 152                   125.0                     118.0
# 153                   134.0                     139.0
# 154                   152.0                     150.0
# 155                   140.0                     143.0
#
# [156 rows x 5 columns]

# %% [markdown]
# # Task4.4: now let's join two dataset we have prepared

# %% [markdown]
# Corona Dataset :

# %%
corona_data.head(10)
# Out:
#                      max infection rate
# Country/Region
# Afghanistan                       915.0
# Albania                            90.0
# Algeria                           475.0
# Andorra                            79.0
# Angola                             47.0
# Antigua and Barbuda                39.0
# Argentina                        3663.0
# Armenia                           771.0
# Australia                         497.0
# Austria                          1321.0

# %% [markdown]
# World happiness report Dataset :

# %%
world_happiness_report.head(10)
# Out:
#   Country (region)  Overall Rank  SD of Ladder  Positive affect  \
# 0          Finland             1             4             41.0
# 1          Denmark             2            13             24.0
# 2           Norway             3             8             16.0
# 3          Iceland             4             9              3.0
# 4      Netherlands             5             1             12.0
# 5      Switzerland             6            11             44.0
# 6           Sweden             7            18             34.0
# 7      New Zealand             8            15             22.0
# 8           Canada             9            23             18.0
# 9          Austria            10            10             64.0
#
#    Negative affect  Social support  Log of GDP\nper capita  \
# 0             10.0             2.0                    22.0
# 1             26.0             4.0                    14.0
# 2             29.0             3.0                     7.0
# 3              3.0             1.0                    15.0
# 4             25.0            15.0                    12.0
# 5             21.0            13.0                     8.0
# 6              8.0            25.0                    13.0
# 7             12.0             5.0                    26.0
# 8             49.0            20.0                    19.0
# 9             24.0            31.0                    16.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0
# 5                       4.0
# 6                      17.0
# 7                      14.0
# 8                       8.0
# 9                      15.0

# %%
data = world_happiness_report.join(corona_data.head()).copy()
data.head(10)
# Out:
#   Country (region)  Overall Rank  SD of Ladder  Positive affect  \
# 0          Finland             1             4             41.0
# 1          Denmark             2            13             24.0
# 2           Norway             3             8             16.0
# 3          Iceland             4             9              3.0
# 4      Netherlands             5             1             12.0
# 5      Switzerland             6            11             44.0
# 6           Sweden             7            18             34.0
# 7      New Zealand             8            15             22.0
# 8           Canada             9            23             18.0
# 9          Austria            10            10             64.0
#
#    Negative affect  Social support  Log of GDP\nper capita  \
# 0             10.0             2.0                    22.0
# 1             26.0             4.0                    14.0
# 2             29.0             3.0                     7.0
# 3              3.0             1.0                    15.0
# 4             25.0            15.0                    12.0
# 5             21.0            13.0                     8.0
# 6              8.0            25.0                    13.0
# 7             12.0             5.0                    26.0
# 8             49.0            20.0                    19.0
# 9             24.0            31.0                    16.0
#
#    Healthy life\nexpectancy  max infection rate
# 0                      27.0                 NaN
# 1                      23.0                 NaN
# 2                      12.0                 NaN
# 3                      13.0                 NaN
# 4                      18.0                 NaN
# 5                       4.0                 NaN
# 6                      17.0                 NaN
# 7                      14.0                 NaN
# 8                       8.0                 NaN
# 9                      15.0                 NaN

# %% [markdown]
# # Task 4.5: correlation matrix

# %%
data.corr()
# it is representing the correlation between every two columns of our dataset
# Out:
#                           Overall Rank  SD of Ladder  Positive affect  \
# Overall Rank                  1.000000      0.539362         0.491432
# SD of Ladder                  0.539362      1.000000         0.085381
# Positive affect               0.491432      0.085381         1.000000
# Negative affect               0.523643      0.619267         0.389697
# Social support                0.817842      0.599464         0.386269
# Log of GDP\nper capita        0.813367      0.629662         0.304522
# Healthy life\nexpectancy      0.816740      0.611376         0.332839
# max infection rate                 NaN           NaN              NaN
#
#                           Negative affect  Social support  \
# Overall Rank                     0.523643        0.817842
# SD of Ladder                     0.619267        0.599464
# Positive affect                  0.389697        0.386269
# Negative affect                  1.000000        0.621888
# Social support                   0.621888        1.000000
# Log of GDP\nper capita           0.542143        0.772912
# Healthy life\nexpectancy         0.488649        0.740728
# max infection rate                    NaN             NaN
#
#                           Log of GDP\nper capita  Healthy life\nexpectancy  \
# Overall Rank                            0.813367                  0.816740
# SD of Ladder                            0.629662                  0.611376
# Positive affect                         0.304522                  0.332839
# Negative affect                         0.542143                  0.488649
# Social support                          0.772912                  0.740728
# Log of GDP\nper capita                  1.000000                  0.847580
# Healthy life\nexpectancy                0.847580                  1.000000
# max infection rate                           NaN                       NaN
#
#                           max infection rate
# Overall Rank                             NaN
# SD of Ladder                             NaN
# Positive affect                          NaN
# Negative affect                          NaN
# Social support                           NaN
# Log of GDP\nper capita                   NaN
# Healthy life\nexpectancy                 NaN
# max infection rate                       NaN

# %% [markdown]
# # Task 5: Visualization of the results

# %% [markdown]
# Our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis.

# %%
data.head(10)
# Out:
#   Country (region)  Overall Rank  SD of Ladder  Positive affect  \
# 0          Finland             1             4             41.0
# 1          Denmark             2            13             24.0
# 2           Norway             3             8             16.0
# 3          Iceland             4             9              3.0
# 4      Netherlands             5             1             12.0
# 5      Switzerland             6            11             44.0
# 6           Sweden             7            18             34.0
# 7      New Zealand             8            15             22.0
# 8           Canada             9            23             18.0
# 9          Austria            10            10             64.0
#
#    Negative affect  Social support  Log of GDP\nper capita  \
# 0             10.0             2.0                    22.0
# 1             26.0             4.0                    14.0
# 2             29.0             3.0                     7.0
# 3              3.0             1.0                    15.0
# 4             25.0            15.0                    12.0
# 5             21.0            13.0                     8.0
# 6              8.0            25.0                    13.0
# 7             12.0             5.0                    26.0
# 8             49.0            20.0                    19.0
# 9             24.0            31.0                    16.0
#
#    Healthy life\nexpectancy  max infection rate
# 0                      27.0                 NaN
# 1                      23.0                 NaN
# 2                      12.0                 NaN
# 3                      13.0                 NaN
# 4                      18.0                 NaN
# 5                       4.0                 NaN
# 6                      17.0                 NaN
# 7                      14.0                 NaN
# 8                       8.0                 NaN
# 9                      15.0                 NaN

# %% [markdown]
# # Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x = data['Log of GDP\nper capita']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# # Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# # Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life\nexpectancy']
y = data['max infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
# mannu
